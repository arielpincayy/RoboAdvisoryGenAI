# %%
import pandas as pd

df = pd.read_excel('data/BankChurners - Completa v1.xlsx', sheet_name='Transacciones vs ID cuestomer')
df
# Out:
#        CustomerID TransactionID AccountID  TransactionAmount  \
# 0       708082083      TX001313   AC00001              47.79
# 1       708082083      TX002017   AC00001             212.97
# 2       708083283      TX000021   AC00002              59.32
# 3       708083283      TX000062   AC00002             263.99
# 4       708083283      TX001029   AC00002             516.47
# ...           ...           ...       ...                ...
# 12137   828288333      TX012001   AC10126             256.95
# 12138   828291858      TX012002   AC10127             406.12
# 12139   828294933      TX012003   AC10128             156.26
# 12140   828298908      TX012004   AC10129             317.12
# 12141   824168808      TX012005   AC10130              88.38
#
#           TransactionDate TransactionType        Location DeviceID  \
# 0     2023-09-15 17:00:20           Debit          Denver  D000649
# 1     2023-11-14 16:56:34           Debit         Atlanta  D000492
# ...

# %%
df.to_csv("data/Transacciones_vs_ID_cuestomer.csv", index=False)
